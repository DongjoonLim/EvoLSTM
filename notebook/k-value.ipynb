# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set_style("whitegrid")

lstm = [0.2218, 0.207, 0.206, 0.204, 0.218, 0.277]
DeepEvoLSTM = [0.207, 0.189, 0.1826, 0.1817, 0.216, 0.258]
DeepEvoLSTM2 = [0.210, 0.194, 0.1874, 0.1856, 0.198, 0.263]
table = [0.22001797896458855, 0.2009239130577984, 0.1988374347093904, 0.19570464211222716, 0.19491412390645477, 0.19454299455827476]
x = [1, 5, 11, 15, 21, 39]
# x2 = [1,5]

plt.plot(x,DeepEvoLSTM, label = 'EvoLSTM 1 layer')
plt.plot(x,DeepEvoLSTM2, label = 'EvoLSTM 2 layer')
plt.plot(x,lstm, label = 'biLSTM')
plt.plot(x,table[:], label = 'freqTable')
plt.xlim(0,40)
plt.ylim(0.18,0.28)
plt.xlabel('Context size (K)')
plt.ylabel('Cross Entropy Loss')
# plt.title("K value")
plt.legend()
plt.show()
