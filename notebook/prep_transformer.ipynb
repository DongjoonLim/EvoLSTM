# %%
from sklearn.preprocessing import LabelEncoder
from bio import AlignIO
from Bio.Align import MultipleSeqAlignment
from Bio.SeqRecord import SeqRecord
from Bio import SeqIO
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from keras_preprocessing import sequence
import sklearn
import numpy as np
import re
import pickle

# %%
seq_length = 11
def string_to_array(my_string):
    my_string = my_string.lower()
    my_string = re.sub('[^acgt0]', 'z', my_string)
    my_array = np.array(list(my_string))
    return my_array

def readmaf(start, end, filename):
    count = 0
    oldlist =[]
    align = AlignIO.parse(filename, "maf")
    for multiple_alignment in align:
        count = count+1
        if count >start and count<=end:
            oldlist.append(multiple_alignment)
        elif count>end:
            break
    return oldlist

#oldlist stores MSAs
oldlist = readmaf(0, 100000, "data/chr2.anc.maf")
print(oldlist[1][1])
print(dir(oldlist[1]))
print(oldlist[1][0].id)
#print(oldlist[2])
# Out:
# ID: panTro4.chr2A
# Name: panTro4.chr2A
# Number of features: 0
# /start=4703
# /size=1
# /strand=1
# /srcSize=113622374
# Seq('a', SingleLetterAlphabet())
# ['__add__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_alphabet', '_annotations', '_append', '_get_per_column_annotations', '_per_col_annotations', '_records', '_set_per_column_annotations', '_str_line', 'add_sequence', 'annotations', 'append', 'column_annotations', 'extend', 'format', 'get_alignment_length', 'sort']
# hg38.chr2

# %%
print(len(oldlist))
# Out:
# 100000

# %%
#alignList stores alignments between direct ancestor and descendent
def getAlign(inputList):
    alignList = []
    zeros = ''
    anc = ''
    des = ''
    for i in range(len(inputList)):
        # index for the dog
        indexDes = -1
        indexAnc = -1

        for j in range(len(inputList[i])):
            if len(inputList[i][j])>=10 and 'canFam3' in inputList[i][j].id  :
                indexDes = j
            elif len(inputList[i][j])>=10 and inputList[i][j].id == '_CMAOL': #'_RMPC' :
                indexAnc = j
        if indexDes!=-1 and indexAnc!=-1:
            des = des+str(inputList[i][indexDes].seq)
            anc = anc+str(inputList[i][indexAnc].seq)

    return anc, des


anc, des = getAlign(oldlist)

def tokenize(anc):
    token = []
    for i in range(len(anc)-seq_length):
        token.append(list(anc[i:i+seq_length]))
    return token
anc = tokenize(anc)
des = tokenize(des)

with open('ancestral', 'wb') as fp:
    pickle.dump(anc, fp)
    
with open('descendant', 'wb') as f:
    pickle.dump(des, f)

# %%
for i in range(1000):
    print(''.join(anc[i]), ''.join(des[i]))
    if ''.join(anc[i]) == ''.join(des[i]):
        print(True)
# Out:
# AAGACAG-AAA AAGAGAG-AAA
# AGACAG-AAAC AGAGAG-AAAC
# GACAG-AAACT GAGAG-AAACT
# ACAG-AAACTA AGAG-AAACTA
# CAG-AAACTAA GAG-AAACTAA
# AG-AAACTAAA AG-AAACTAAA
# True
# G-AAACTAAAG G-AAACTAAAG
# True
# -AAACTAAAGC -AAACTAAAGC
# True
# AAACTAAAGCT AAACTAAAGCT
# True
# AACTAAAGCTG AACTAAAGCTG
# True
# ACTAAAGCTGA ACTAAAGCTGA
# True
# CTAAAGCTGAG CTAAAGCTGAG
# True
# TAAAGCTGAGC TAAAGCTGAGC
# True
# AAAGCTGAGCC AAAGCTGAGCC
# True
# AAGCTGAGCCA AAGCTGAGCCA
# True
# AGCTGAGCCAT AGCTGAGCCAT
# True
# GCTGAGCCATA GCTGAGCCATA
# True
# CTGAGCCATAG CTGAGCCATAG
# True
# TGAGCCATAGG TGAGCCATAGG
# True
# GAGCCATAGGC GAGCCATAGGC
# True
# AGCCATAGGCT AGCCATAGGCT
# True
# GCCATAGGCTA GCCATAGGCTA
# True
# CCATAGGCTAC CCATAGGCTAC
# True
# CATAGGCTACA CATAGGCTACA
# True
# ATAGGCTACAA ATAGGCTACAA
# True
# TAGGCTACAA- TAGGCTACAA-
# True
# AGGCTACAA-- AGGCTACAA--
# True
# GGCTACAA--- GGCTACAA---
# True
# GCTACAA---- GCTACAA----
# True
# CTACAA----- CTACAA-----
# True
# TACAA------ TACAA------
# True
# ACAA------- ACAA-------
# True
# CAA-------- CAA--------
# True
# AA--------- AA---------
# True
# A---------- A----------
# True
# ----------C ----------C
# True
# ---------CT ---------CT
# True
# --------CTG --------CTG
# True
# -------CTGA -------CTGA
# True
# ------CTGAT ------CTGAC
# -----CTGATC -----CTGACC
# ----CTGATCT ----CTGACCT
# ---CTGATCTG ---CTGACCTG
# --CTGATCTGA --CTGACCTGA
# -CTGATCTGAC -CTGACCTGAC
# CTGATCTGACA CTGACCTGAC-
# TGATCTGACAA TGACCTGAC--
# GATCTGACAAT GACCTGAC---
# ATCTGACAATA ACCTGAC----
# TCTGACAATAA CCTGAC----A
# CTGACAATAAG CTGAC----AG
# TGACAATAAGT TGAC----AGT
# GACAATAAGTC GAC----AGTC
# ACAATAAGTCA AC----AGTCA
# CAATAAGTCAG C----AGTCAG
# AATAAGTCAGG ----AGTCAGA
# ATAAGTCAGGG ---AGTCAGAG
# TAAGTCAGGGG --AGTCAGAGG
# AAGTCAGGGGA -AGTCAGAGGA
# AGTCAGGGGAA AGTCAGAGGAA
# GTCAGGGGAA- GTCAGAGGAA-
# TCAGGGGAA-A TCAGAGGAA-A
# CAGGGGAA-AG CAGAGGAA-AG
# AGGGGAA-AGA AGAGGAA-AGC
# GGGGAA-AGAA GAGGAA-AGCA
# GGGAA-AGAAG AGGAA-AGCAG
# GGAA-AGAAGG GGAA-AGCAGG
# GAA-AGAAGGG GAA-AGCAGGG
# AA-AGAAGGGC AA-AGCAGGGC
# A-AGAAGGGCA A-AGCAGGGCA
# -AGAAGGGCAC -AGCAGGGCAT
# AGAAGGGCACA AGCAGGGCATA
# GAAGGGCACAG GCAGGGCATAG
# AAGGGCACAGA CAGGGCATAGA
# AGGGCACAGAG AGGGCATAGAG
# GGGCACAGAGA GGGCATAGAGA
# GGCACAGAGAG GGCATAGAGAG
# GCACAGAGAGA GCATAGAGAGG
# CACAGAGAGA- CATAGAGAGG-
# ACAGAGAGA-T ATAGAGAGG-T
# CAGAGAGA-TT TAGAGAGG-TT
# AGAGAGA-TTT AGAGAGG-TTT
# GAGAGA-TTTG GAGAGG-TTTG
# AGAGA-TTTGA AGAGG-TTTGA
# GAGA-TTTGAA GAGG-TTTGAA
# AGA-TTTGAAC AGG-TTTGAAC
# GA-TTTGAACA GG-TTTGAACA
# A-TTTGAACAT G-TTTGAACAC
# -TTTGAACATT -TTTGAACACT
# TTTGAACATTT TTTGAACACTT
# TTGAACATTTG TTGAACACTTG
# TGAACATTTGT TGAACACTTGC
# GAACATTTGTC GAACACTTGCC
# AACATTTGTCC AACACTTGCCC
# ACATTTGTCCA ACACTTGCCCA
# CATTTGTCCAC CACTTGCCCAC
# ATTTGTCCACT ACTTGCCCACT
# TTTGTCCACTA CTTGCCCACTA
# TTGTCCACTAA TTGCCCACTAA
# TGTCCACTAAA TGCCCACTAAA
# GTCCACTAAAA GCCCACTAAAA
# TCCACTAAAA- CCCACTAAAA-
# CCACTAAAA-- CCACTAAAA--
# True
# CACTAAAA--- CACTAAAA---
# True
# ACTAAAA---- ACTAAAA----
# True
# CTAAAA----- CTAAAA-----
# True
# TAAAA------ TAAAA------
# True
# AAAA------A AAAA------A
# True
# AAA------A- AAA------AT
# AA------A-A AA------ATA
# A------A-AA A------ATAA
# ------A-AAT ------ATAAT
# -----A-AATG -----ATAATG
# ----A-AATGC ----ATAATGC
# ---A-AATGCT ---ATAATGCT
# --A-AATGCTA --ATAATGCTA
# -A-AATGCTAG -ATAATGCTAG
# A-AATGCTAGA ATAATGCTAGA
# -AATGCTAGAA TAATGCTAGAA
# AATGCTAGAAT AATGCTAGAAT
# True
# ATGCTAGAATT ATGCTAGAATT
# True
# TGCTAGAATTC TGCTAGAATTC
# True
# GCTAGAATTCA GCTAGAATTCA
# True
# CTAGAATTCAT CTAGAATTCAT
# True
# TAGAATTCATA TAGAATTCATA
# True
# AGAATTCATAA AGAATTCATA-
# GAATTCATAAT GAATTCATA--
# AATTCATAATA AATTCATA--A
# ATTCATAATAA ATTCATA--AA
# TTCATAATAAA TTCATA--AAA
# TCATAATAAAT TCATA--AAAT
# CATAATAAATT CATA--AAATT
# ATAATAAATTG ATA--AAATTG
# TAATAAATTGA TA--AAATTGA
# AATAAATTGAT A--AAATTGAT
# ATAAATTGATT --AAATTGATT
# TAAATTGATTC -AAATTGATTC
# AAATTGATTCC AAATTGATTCC
# True
# AATTGATTCCA AATTGATTCCA
# True
# ATTGATTCCAA ATTGATTCCAA
# True
# TTGATTCCAAG TTGATTCCAAG
# True
# TGATTCCAAGT TGATTCCAAGT
# True
# GATTCCAAGT- GATTCCAAGT-
# True
# ATTCCAAGT-- ATTCCAAGT--
# True
# TTCCAAGT--- TTCCAAGT---
# True
# TCCAAGT---- TCCAAGT----
# True
# CCAAGT----A CCAAGT----A
# True
# CAAGT----AA CAAGT----AA
# True
# AAGT----AAA AAGT----AAA
# True
# AGT----AAA- AGT----AAA-
# True
# GT----AAA-- GT----AAA--
# True
# T----AAA--A T----AAA---
# ----AAA--AA ----AAA----
# ---AAA--AAA ---AAA-----
# --AAA--AAAT --AAA------
# -AAA--AAATG -AAA-------
# AAA--AAATGT AAA--------
# AA--AAATGTT AA---------
# A--AAATGTTC A----------
# --AAATGTTCA -----------
# -AAATGTTCA- -----------
# AAATGTTCA-A -----------
# AATGTTCA-A- -----------
# ATGTTCA-A-- -----------
# TGTTCA-A--- -----------
# GTTCA-A---- -----------
# TTCA-A----- -----------
# TCA-A------ -----------
# CA-A------T ----------T
# A-A------TA ---------TA
# -A------TAA --------TAA
# A------TAAT -------TAAT
# ------TAATA ------TAATA
# True
# -----TAATAA -----TAATAA
# True
# ----TAATAAT ----TAATAAT
# True
# ---TAATAATA ---TAATAATA
# True
# --TAATAATAA --TAATAATAA
# True
# -TAATAATAAT -TAATAATAAT
# True
# TAATAATAATC TAATAATAATC
# True
# AATAATAATCA AATAATAATCA
# True
# ATAATAATCAA ATAATAATCAA
# True
# TAATAATCAAT TAATAATCAAT
# True
# AATAATCAATA AATAATCAATA
# True
# ATAATCAATAA ATAATCAATAA
# True
# TAATCAATAA- TAATCAATAA-
# True
# AATCAATAA-- AATCAATAA--
# True
# ATCAATAA--- ATCAATAA---
# True
# TCAATAA---C TCAATAA---C
# True
# CAATAA---CA CAATAA---CA
# True
# AATAA---CAA AATAA---CAA
# True
# ATAA---CAAA ATAA---CAAA
# True
# TAA---CAAA- TAA---CAAA-
# True
# AA---CAAA-- AA---CAAA--
# True
# A---CAAA--- A---CAAA---
# True
# ---CAAA---- ---CAAA----
# True
# --CAAA----G --CAAA-----
# -CAAA----GG -CAAA-----G
# CAAA----GGG CAAA-----GG
# AAA----GGGA AAA-----GGA
# AA----GGGAT AA-----GGAT
# A----GGGATC A-----GGATC
# ----GGGATCT -----GGATCT
# ---GGGATCTA ----GGATCTA
# --GGGATCTAC ---GGATCTAC
# -GGGATCTACA --GGATCTACA
# GGGATCTACAG -GGATCTACAG
# GGATCTACAGT GGATCTACAGT
# True
# GATCTACAGTA GATCTACAGTA
# True
# ATCTACAGTAG ATCTACAGTAG
# True
# TCTACAGTAGG TCTACAGTAGG
# True
# CTACAGTAGGA CTACAGTAGGA
# True
# TACAGTAGGAA TACAGTAGGAA
# True
# ACAGTAGGAAC ACAGTAGGAAC
# True
# CAGTAGGAACT CAGTAGGAACT
# True
# AGTAGGAACTG AGTAGGAACT-
# GTAGGAACTGG GTAGGAACT-G
# TAGGAACTGG- TAGGAACT-G-
# AGGAACTGG-A AGGAACT-G-A
# GGAACTGG-AA GGAACT-G-AA
# GAACTGG-AAC GAACT-G-AAT
# AACTGG-AAC- AACT-G-AAT-
# ACTGG-AAC-A ACT-G-AAT-A
# CTGG-AAC-AG CT-G-AAT-AG
# TGG-AAC-AGA T-G-AAT-AGA
# GG-AAC-AGAT -G-AAT-AGAT
# G-AAC-AGATC G-AAT-AGATC
# -AAC-AGATCT -AAT-AGATCT
# AAC-AGATCTC AAT-AGATCTC
# AC-AGATCTCA AT-AGATCTCA
# C-AGATCTCAC T-AGATCTCAC
# -AGATCTCAC- -AGATCTCAC-
# True
# AGATCTCAC-- AGATCTCAC--
# True
# GATCTCAC--- GATCTCAC---
# True
# ATCTCAC---A ATCTCAC---A
# True
# TCTCAC---AA TCTCAC---AA
# True
# CTCAC---AA- CTCAC---AA-
# True
# TCAC---AA-- TCAC---AA--
# True
# CAC---AA--- CAC---AA---
# True
# AC---AA---- AC---AA----
# True
# C---AA----A C---AA----A
# True
# ---AA----AT ---AA----AT
# True
# --AA----ATG --AA----ATG
# True
# -AA----ATGG -AA----ATGG
# True
# AA----ATGGG AA----ATGGG
# True
# A----ATGGGT A----ATGGGT
# True
# ----ATGGGTT ----ATGGGTT
# True
# ---ATGGGTTT ---ATGGGTTT
# True
# --ATGGGTTTC --ATGGGTTTC
# True
# -ATGGGTTTCA -ATGGGTTTCA
# True
# ATGGGTTTCAG ATGGGTTTCAG
# True
# TGGGTTTCAGT TGGGTTTCAGC
# GGGTTTCAGTT GGGTTTCAGCT
# GGTTTCAGTTT GGTTTCAGCTT
# GTTTCAGTTTT GTTTCAGCTTG
# TTTCAGTTTTG TTTCAGCTTGG
# TTCAGTTTTGA TTCAGCTTGGA
# TCAGTTTTGA- TCAGCTTGGA-
# CAGTTTTGA-- CAGCTTGGA--
# AGTTTTGA--- AGCTTGGA---
# GTTTTGA---- GCTTGGA----
# TTTTGA----- CTTGGA-----
# TTTGA------ TTGGA------
# TTGA------- TGGA-------
# TGA-------- GGA--------
# GA--------- GA---------
# True
# A---------- A----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------A ----------A
# True
# ---------AG ---------AG
# True
# --------AGG --------AGG
# True
# -------AGGA -------AGGA
# True
# ------AGGAA ------AGGAG
# -----AGGAAT -----AGGAGT
# ----AGGAATG ----AGGAGTT
# ---AGGAATGT ---AGGAGTTT
# --AGGAATGTC --AGGAGTTTC
# -AGGAATGTCT -AGGAGTTTCT
# AGGAATGTCTC AGGAGTTTCTC
# GGAATGTCTCT GGAGTTTCTCT
# GAATGTCTCTG GAGTTTCTCTG
# AATGTCTCTGG AGTTTCTCTGG
# ATGTCTCTGGC GTTTCTCTGGC
# TGTCTCTGGCT TTTCTCTGGCT
# GTCTCTGGCTC TTCTCTGGCTC
# TCTCTGGCTCT TCTCTGGCTCT
# True
# CTCTGGCTCTA CTCTGGCTCTA
# True
# TCTGGCTCTAC TCTGGCTCTAC
# True
# CTGGCTCTACT CTGGCTCTACT
# True
# TGGCTCTACTT TGGCTCTACTT
# True
# GGCTCTACTTC GGCTCTACTTT
# GCTCTACTTCA GCTCTACTTTA
# CTCTACTTCAT CTCTACTTTAT
# TCTACTTCATC TCTACTTTATC
# CTACTTCATCT CTACTTTATCT
# TACTTCATCTT TACTTTATCTT
# ACTTCATCTTC ACTTTATCTTC
# CTTCATCTTCA CTTTATCTTCA
# TTCATCTTCAC TTTATCTTCAC
# TCATCTTCACA TTATCTTCACA
# CATCTTCACAT TATCTTCACAT
# ATCTTCACATG ATCTTCACATA
# TCTTCACATGT TCTTCACATAT
# CTTCACATGTT CTTCACATATT
# TTCACATGTTT TTCACATATTT
# TCACATGTTTG TCACATATTTG
# CACATGTTTGG CACATATTTGC
# ACATGTTTGGA ACATATTTGCA
# CATGTTTGGAT CATATTTGCAT
# ATGTTTGGATT ATATTTGCATT
# TGTTTGGATTG TATTTGCATTG
# GTTTGGATTGT ATTTGCATTGT
# TTTGGATTGTG TTTGCATTGTG
# TTGGATTGTGT TTGCATTGTGT
# TGGATTGTGTG TGCATTGTGTG
# GGATTGTGTG- GCATTGTGTG-
# GATTGTGTG-- CATTGTGTG--
# ATTGTGTG--- ATTGTGTG---
# True
# TTGTGTG---T TTGTGTG---T
# True
# TGTGTG---TG TGTGTG---TG
# True
# GTGTG---TGT GTGTG---TGT
# True
# TGTG---TGTC TGTG---TGTC
# True
# GTG---TGTCA GTG---TGTCA
# True
# TG---TGTCAC TG---TGTCAC
# True
# G---TGTCACA G---TGTCACA
# True
# ---TGTCACAA ---TGTCACAA
# True
# --TGTCACAAA --TGTCACAAA
# True
# -TGTCACAAAA -TGTCACAAAA
# True
# TGTCACAAAAG TGTCACAAAAG
# True
# GTCACAAAAGA GTCACAAAAGA
# True
# TCACAAAAGAG TCACAAAAGAG
# True
# CACAAAAGAGG CACAAAAGAG-
# ACAAAAGAGGC ACAAAAGAG--
# CAAAAGAGGCT CAAAAGAG--T
# AAAAGAGGCTT AAAAGAG--TT
# AAAGAGGCTT- AAAGAG--TT-
# AAGAGGCTT-- AAGAG--TT--
# AGAGGCTT--T AGAG--TT--T
# GAGGCTT--T- GAG--TT--TG
# AGGCTT--T-- AG--TT--TG-
# GGCTT--T--- G--TT--TG--
# GCTT--T---- --TT--TG--G
# CTT--T----- -TT--TG--GT
# TT--T------ TT--TG--GTG
# T--T------- T--TG--GTGA
# --T-------G --TG--GTGAG
# -T-------GA -TG--GTGAGA
# T-------GAA TG--GTGAGAA
# -------GAAA G--GTGAGAAA
# ------GAAAG --GTGAGAAAG
# -----GAAAGT -GTGAGAAAGT
# ----GAAAGTC GTGAGAAAGTT
# ---GAAAGTCA TGAGAAAGTTA
# --GAAAGTCAC GAGAAAGTTAT
# -GAAAGTCACT AGAAAGTTATT
# GAAAGTCACTG GAAAGTTATTG
# AAAGTCACTGG AAAGTTATTGG
# AAGTCACTGGA AAGTTATTGGA
# AGTCACTGGAT AGTTATTGGAT
# GTCACTGGATT GTTATTGGATT
# TCACTGGATTC TTATTGGATTC
# CACTGGATTCT TATTGGATTCT
# ACTGGATTCTC ATTGGATTCTC
# CTGGATTCTCT TTGGATTCTCT
# TGGATTCTCTA TGGATTCTCTA
# True
# GGATTCTCTAA GGATTCTCTAA
# True
# GATTCTCTAAG GATTCTCTAAG
# True
# ATTCTCTAAGA ATTCTCTAAGA
# True
# TTCTCTAAGAA TTCTCTAAGAA
# True
# TCTCTAAGAAG TCTCTAAGAAG
# True
# CTCTAAGAAG- CTCTAAGAAG-
# True
# TCTAAGAAG-T TCTAAGAAG-T
# True
# CTAAGAAG-TC CTAAGAAG-TC
# True
# TAAGAAG-TCT TAAGAAG-TCT
# True
# AAGAAG-TCTG AAGAAG-TCTG
# True
# AGAAG-TCTGG AGAAG-TCTGG
# True
# GAAG-TCTGGG GAAG-TCTGGG
# True
# AAG-TCTGGGA AAG-TCTGGGA
# True
# AG-TCTGGGAC AG-TCTGGGAC
# True
# G-TCTGGGACT G-TCTGGGACT
# True
# -TCTGGGACTC -TCTGGGACTC
# True
# TCTGGGACTCC TCTGGGACTCC
# True
# CTGGGACTCCA CTGGGACTCCA
# True
# TGGGACTCCAC TGGGACTCCAC
# True
# GGGACTCCACT GGGACTCCACT
# True
# GGACTCCACTG GGACTCCACTG
# True
# GACTCCACTGC GACTCCACTGC
# True
# ACTCCACTGCT ACTCCACTGCT
# True
# CTCCACTGCTG CTCCACTGCTG
# True
# TCCACTGCTGG TCCACTGCTGG
# True
# CCACTGCTGGA CCACTGCTGGA
# True
# CACTGCTGGAA CACTGCTGGAA
# True
# ACTGCTGGAAA ACTGCTGGAAA
# True
# CTGCTGGAAAG CTGCTGGAAAG
# True
# TGCTGGAAAGA TGCTGGAAAGA
# True
# GCTGGAAAGAA GCTGGAAAGAA
# True
# CTGGAAAGAAA CTGGAAAGAAA
# True
# TGGAAAGAAAA TGGAAAGAAAA
# True
# GGAAAGAAAAG GGAAAGAAAAG
# True
# GAAAGAAAAG- GAAAGAAAAG-
# True
# AAAGAAAAG-- AAAGAAAAG--
# True
# AAGAAAAG--T AAGAAAAG--T
# True
# AGAAAAG--TT AGAAAAG--T-
# GAAAAG--TTT GAAAAG--T--
# AAAAG--TTTG AAAAG--T---
# AAAG--TTTGT AAAG--T---T
# AAG--TTTGTT AAG--T---TT
# AG--TTTGTTG AG--T---TTG
# G--TTTGTTGA G--T---TTGA
# --TTTGTTGAG --T---TTGAG
# -TTTGTTGAG- -T---TTGAG-
# TTTGTTGAG-- T---TTGAG--
# TTGTTGAG--- ---TTGAG---
# TGTTGAG---- --TTGAG----
# GTTGAG----- -TTGAG-----
# TTGAG-----A TTGAG-----A
# True
# TGAG-----AA TGAG-----AA
# True
# GAG-----AAA GAG-----AAA
# True
# AG-----AAAA AG-----AAAC
# G-----AAAAA G-----AAACA
# -----AAAAAC -----AAACAC
# ----AAAAACT ----AAACACC
# ---AAAAACTG ---AAACACCG
# --AAAAACTGA --AAACACCGA
# -AAAAACTGAG -AAACACCGAA
# AAAAACTGAGT AAACACCGAAT
# AAAACTGAGTT AACACCGAATT
# AAACTGAGTTG ACACCGAATTG
# AACTGAGTTGG CACCGAATTGG
# ACTGAGTTGGA ACCGAATTGGA
# CTGAGTTGGAG CCGAATTGGAG
# TGAGTTGGAGC CGAATTGGAGC
# GAGTTGGAGCA GAATTGGAGCA
# AGTTGGAGCAG AATTGGAGCAG
# GTTGGAGCAGG ATTGGAGCAGG
# TTGGAGCAGG- TTGGAGCAGG-
# True
# TGGAGCAGG-C TGGAGCAGG-C
# True
# GGAGCAGG-CC GGAGCAGG-CC
# True
# GAGCAGG-CCG GAGCAGG-CCG
# True
# AGCAGG-CCGT AGCAGG-CCGT
# True
# GCAGG-CCGTC GCAGG-CCGTC
# True
# CAGG-CCGTCC CAGG-CCGTCC
# True
# AGG-CCGTCCC AGG-CCGTCCC
# True
# GG-CCGTCCCT GG-CCGTCCCT
# True
# G-CCGTCCCTG G-CCGTCCCTG
# True
# -CCGTCCCTGG -CCGTCCCTGG
# True
# CCGTCCCTGGA CCGTCCCTGGA
# True
# CGTCCCTGGAG CGTCCCTGGAG
# True
# GTCCCTGGAGT GTCCCTGGAGT
# True
# TCCCTGGAGTG TCCCTGGAGTG
# True
# CCCTGGAGTGA CCCTGGAGTGG
# CCTGGAGTGAA CCTGGAGTGGG
# CTGGAGTGAAG CTGGAGTGGGG
# TGGAGTGAAGC TGGAGTGGGGC
# GGAGTGAAGCA GGAGTGGGGCA
# GAGTGAAGCAG GAGTGGGGCAG
# AGTGAAGCAGA AGTGGGGCAGA
# GTGAAGCAGAA GTGGGGCAGAA
# TGAAGCAGAAC TGGGGCAGAAT
# GAAGCAGAACG GGGGCAGAATG
# AAGCAGAACGT GGGCAGAATGT
# AGCAGAACGTT GGCAGAATGTT
# GCAGAACGTTC GCAGAATGTTC
# CAGAACGTTCC CAGAATGTTCC
# AGAACGTTCCT AGAATGTTCCT
# GAACGTTCCTC GAATGTTCCTC
# AACGTTCCTCA AATGTTCCTCA
# ACGTTCCTCAA ATGTTCCTCAG
# CGTTCCTCAAC TGTTCCTCAGC
# GTTCCTCAACA GTTCCTCAGCA
# TTCCTCAACAA TTCCTCAGCAG
# TCCTCAACAAT TCCTCAGCAGT
# CCTCAACAATC CCTCAGCAGTC
# CTCAACAATCT CTCAGCAGTCT
# TCAACAATCTG TCAGCAGTCTG
# CAACAATCTGC CAGCAGTCTGC
# AACAATCTGCT AGCAGTCTGCT
# ACAATCTGCTT GCAGTCTGCTT
# CAATCTGCTTT CAGTCTGCTTT
# AATCTGCTTTT AGTCTGCTTTT
# ATCTGCTTTT- GTCTGCTTTT-
# TCTGCTTTT-A TCTGCTTTT-A
# True
# CTGCTTTT-AT CTGCTTTT-AT
# True
# TGCTTTT-ATG TGCTTTT-ATG
# True
# GCTTTT-ATGC GCTTTT-ATGC
# True
# CTTTT-ATGCA CTTTT-ATGCA
# True
# TTTT-ATGCAT TTTT-ATGCAT
# True
# TTT-ATGCATC TTT-ATGCATC
# True
# TT-ATGCATCC TT-ATGCATCC
# True
# T-ATGCATCCT T-ATGCATCCT
# True
# -ATGCATCCTG -ATGCATCCTG
# True
# ATGCATCCTGT ATGCATCCTGG
# TGCATCCTGTG TGCATCCTGGG
# GCATCCTGTGC GCATCCTGGGC
# CATCCTGTGCT CATCCTGGGCT
# ATCCTGTGCTG ATCCTGGGCTG
# TCCTGTGCTGT TCCTGGGCTG-
# CCTGTGCTGT- CCTGGGCTG--
# CTGTGCTGT-- CTGGGCTG---
# TGTGCTGT--- TGGGCTG----
# GTGCTGT---- GGGCTG-----
# TGCTGT----- GGCTG------
# GCTGT------ GCTG-------
# CTGT------- CTG--------
# TGT-------- TG---------
# GT--------G G---------G
# T--------GG ---------GG
# --------GGG --------GGG
# True
# -------GGGC -------GGGT
# ------GGGCT ------GGGTT
# -----GGGCTT -----GGGTTT
# ----GGGCTT- ----GGGTTT-
# ---GGGCTT-- ---GGGTTT--
# --GGGCTT--- --GGGTTT---
# -GGGCTT---- -GGGTTT----
# GGGCTT----- GGGTTT-----
# GGCTT-----A GGTTT-----A
# GCTT-----AA GTTT-----AA
# CTT-----AAC TTT-----AAG
# TT-----AACC TT-----AAGC
# T-----AACCA T-----AAGCA
# -----AACCAA -----AAGCAA
# ----AACCAAA ----AAGCAAA
# ---AACCAAAG ---AAGCAAAG
# --AACCAAAGG --AAGCAAAGG
# -AACCAAAGGT -AAGCAAAGGT
# AACCAAAGGTC AAGCAAAGGTC
# ACCAAAGGTCA AGCAAAGGTCA
# CCAAAGGTCAA GCAAAGGTCAG
# CAAAGGTCAAA CAAAGGTCAGA
# AAAGGTCAAAG AAAGGTCAGA-
# AAGGTCAAAGC AAGGTCAGA-C
# AGGTCAAAGCT AGGTCAGA-CT
# GGTCAAAGCTA GGTCAGA-CTA
# GTCAAAGCTAC GTCAGA-CTAC
# TCAAAGCTACA TCAGA-CTACG
# CAAAGCTACAT CAGA-CTACGT
# AAAGCTACATT AGA-CTACGTT
# AAGCTACATTA GA-CTACGTTA
# AGCTACATTAT A-CTACGTTAT
# GCTACATTATC -CTACGTTATG
# CTACATTATCC CTACGTTATGT
# TACATTATCCA TACGTTATGTG
# ACATTATCCAT ACGTTATGTGT
# CATTATCCATG CGTTATGTGTG
# ATTATCCATGA GTTATGTGTGA
# TTATCCATGA- TTATGTGTGA-
# TATCCATGA-- TATGTGTGA--
# ATCCATGA--- ATGTGTGA---
# TCCATGA---G TGTGTGA---G
# CCATGA---GC GTGTGA---GT
# CATGA---GCG TGTGA---GTG
# ATGA---GCGG GTGA---GTGG
# TGA---GCGGG TGA---GTGGG
# GA---GCGGGG GA---GTGGGG
# A---GCGGGG- A---GTGGGG-
# ---GCGGGG-- ---GTGGGG--
# --GCGGGG--- --GTGGGG---
# -GCGGGG---- -GTGGGG----
# GCGGGG----- GTGGGG-----
# CGGGG-----C TGGGG-----C
# GGGG-----CT GGGG-----CT
# True
# GGG-----CTC GGG-----CTC
# True
# GG-----CTCT GG-----CTCT
# True
# G-----CTCTC G-----CTCTC
# True
# -----CTCTCA -----CTCTCA
# True
# ----CTCTCAC ----CTCTCAC
# True
# ---CTCTCACT ---CTCTCACT
# True
# --CTCTCACTG --CTCTCACTG
# True
# -CTCTCACTGT -CTCTCACTGT
# True
# CTCTCACTGTT CTCTCACTGTT
# True
# TCTCACTGTTC TCTCACTGTTC
# True
# CTCACTGTTCC CTCACTGTTCC
# True
# TCACTGTTCCC TCACTGTTCCC
# True
# CACTGTTCCCT CACTGTTCCCT
# True
# ACTGTTCCCTG ACTGTTCCCTG
# True
# CTGTTCCCTGA CTGTTCCCTGA
# True
# TGTTCCCTGAA TGTTCCCTGAC
# GTTCCCTGAAT GTTCCCTGACT
# TTCCCTGAATT TTCCCTGACTT
# TCCCTGAATTC TCCCTGACTTC
# CCCTGAATTCA CCCTGACTTCG
# CCTGAATTCAG CCTGACTTCGG
# CTGAATTCAGT CTGACTTCGGT
# TGAATTCAGTG TGACTTCGGTG
# GAATTCAGTGG GACTTCGGTGG
# AATTCAGTGGA ACTTCGGTGGA
# ATTCAGTGGAC CTTCGGTGGAC
# TTCAGTGGACA TTCGGTGGACA
# TCAGTGGACAG TCGGTGGACAG
# CAGTGGACAGA CGGTGGACAGA
# AGTGGACAGAC GGTGGACAGAC
# GTGGACAGACA GTGGACAGACA
# True
# TGGACAGACAA TGGACAGACAA
# True
# GGACAGACAAT GGACAGACAAT
# True
# GACAGACAATG GACAGACAATG
# True
# ACAGACAATGA ACAGACAATGA
# True
# CAGACAATGAA CAGACAATGAA
# True
# AGACAATGAAT AGACAATGAAT
# True
# GACAATGAATA GACAATGAATA
# True
# ACAATGAATAG ACAATGAATAG
# True
# CAATGAATAGA CAATGAATAGA
# True
# AATGAATAGAC AATGAATAGAC
# True
# ATGAATAGACT ATGAATAGACT
# True
# TGAATAGACTA TGAATAGACTA
# True
# GAATAGACTAG GAATAGACTAG
# True
# AATAGACTAGT AATAGACTAGT
# True
# ATAGACTAGTT ATAGACTAGTT
# True
# TAGACTAGTTT TAGACTAGTTT
# True
# AGACTAGTTT- AGACTAGTTT-
# True
# GACTAGTTT-- GACTAGTTT--
# True
# ACTAGTTT--- ACTAGTTT---
# True
# CTAGTTT---- CTAGTTT----
# True
# TAGTTT----- TAGTTT-----
# True
# AGTTT------ AGTTT------
# True
# GTTT------- GTTT-------
# True
# TTT-------- TTT--------
# True
# TT--------- TT---------
# True
# T---------- T----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------T ----------T
# True
# ---------TT ---------TT
# True
# --------TTC --------TTC
# True
# -------TTCT -------TTCT
# True
# ------TTCTC ------TTCTC
# True
# -----TTCTCC -----TTCTCC
# True
# ----TTCTCCC ----TTCTCCC
# True
# ---TTCTCCCT ---TTCTCCCT
# True
# --TTCTCCCT- --TTCTCCCT-
# True
# -TTCTCCCT-C -TTCTCCCT-C
# True
# TTCTCCCT-CA TTCTCCCT-CA
# True
# TCTCCCT-CAG TCTCCCT-CAG
# True
# CTCCCT-CAG- CTCCCT-CAG-
# True
# TCCCT-CAG-- TCCCT-CAG--
# True
# CCCT-CAG--- CCCT-CAG---
# True
# CCT-CAG---A CCT-CAG---A
# True
# CT-CAG---AA CT-CAG---AA
# True
# T-CAG---AAC T-CAG---AAC
# True
# -CAG---AACA -CAG---AACA
# True
# CAG---AACAC CAG---AACAC
# True
# AG---AACACA AG---AACACA
# True
# G---AACACAA G---AACACAA
# True
# ---AACACAAT ---AACACAAT
# True
# --AACACAAT- --AACACAAT-
# True
# -AACACAAT-- -AACACAAT--
# True
# AACACAAT--- AACACAAT---
# True
# ACACAAT---- ACACAAT----
# True
# CACAAT----A CACAAT----A
# True
# ACAAT----AT ACAAT----AT
# True
# CAAT----ATC CAAT----ATC
# True
# AAT----ATCT AAT----ATCT
# True
# AT----ATCTA AT----ATCTA
# True
# T----ATCTAC T----ATCTAC
# True
# ----ATCTACA ----ATCTACG
# ---ATCTACAA ---ATCTACGA
# --ATCTACAAA --ATCTACGAG
# -ATCTACAAAT -ATCTACGAGT
# ATCTACAAATA ATCTACGAGTA
# TCTACAAATAC TCTACGAGTAC
# CTACAAATACC CTACGAGTACC
# TACAAATACCC TACGAGTACCC
# ACAAATACCCA ACGAGTACCCA
# CAAATACCCAA CGAGTACCCAA
# AAATACCCAAT GAGTACCCAAT
# AATACCCAATC AGTACCCAATC
# ATACCCAATCT GTACCCAATCT
# TACCCAATCTT TACCCAATCTC
# ACCCAATCTTA ACCCAATCTCT
# CCCAATCTTAG CCCAATCTCTG
# CCAATCTTAGA CCAATCTCTGA
# CAATCTTAGAA CAATCTCTGAA
# AATCTTAGAA- AATCTCTGAA-
# ATCTTAGAA-- ATCTCTGAA--
# TCTTAGAA--- TCTCTGAA---
# CTTAGAA---- CTCTGAA----
# TTAGAA----- TCTGAA-----
# TAGAA------ CTGAA------
# AGAA------- TGAA-------
# GAA-------- GAA--------
# True
# AA--------G AA--------G
# True
# A--------GG A--------GG
# True
# --------GGG --------GGG
# True
# -------GGGA -------GGGA
# True
# ------GGGAT ------GGGAT
# True
# -----GGGATG -----GGGATG
# True
# ----GGGATGT ----GGGATGT
# True
# ---GGGATGTG ---GGGATGTA
# --GGGATGTGG --GGGATGTAG
# -GGGATGTGGC -GGGATGTAGC
# GGGATGTGGCT GGGATGTAGCT
# GGATGTGGCTT GGATGTAGCTT
# GATGTGGCTTA GATGTAGCTTA
# ATGTGGCTTAC ATGTAGCTTAC
# TGTGGCTTACT TGTAGCTTACT
# GTGGCTTACTA GTAGCTTACTA
# TGGCTTACTA- TAGCTTACTA-
# GGCTTACTA-A AGCTTACTA-A
# GCTTACTA-AA GCTTACTA-AA
# True
# CTTACTA-AAA CTTACTA-AAA
# True
# TTACTA-AAA- TTACTA-AAA-
# True
# TACTA-AAA-- TACTA-AAA--
# True
# ACTA-AAA--T ACTA-AAA--T
# True
# CTA-AAA--TG CTA-AAA--TG
# True
# TA-AAA--TGT TA-AAA--TGT
# True
# A-AAA--TGTC A-AAA--TGTC
# True
# -AAA--TGTCA -AAA--TGTCA
# True
# AAA--TGTCAG AAA--TGTCAG
# True
# AA--TGTCAGA AA--TGTCAGG
# A--TGTCAGAT A--TGTCAGGT
# --TGTCAGATG --TGTCAGGTG
# -TGTCAGATGT -TGTCAGGTGT
# TGTCAGATGTA TGTCAGGTGTA
# GTCAGATGTA- GTCAGGTGTA-
# TCAGATGTA-A TCAGGTGTA-A
# CAGATGTA-AT CAGGTGTA-AT
# AGATGTA-AT- AGGTGTA-AT-
# GATGTA-AT-T GGTGTA-AT-T
# ATGTA-AT-T- GTGTA-AT-T-
# TGTA-AT-T-- TGTA-AT-T--
# True
# GTA-AT-T--- GTA-AT-T---
# True
# TA-AT-T---- TA-AT-T----
# True
# A-AT-T----- A-AT-T-----
# True
# -AT-T-----T -AT-T-----T
# True
# AT-T-----TT AT-T-----TT
# True
# T-T-----TTG T-T-----TTG
# True
# -T-----TTGC -T-----TTGC
# True
# T-----TTGCT T-----TTGCT
# True
# -----TTGCTA -----TTGCTA
# True
# ----TTGCTAT ----TTGCTAT
# True
# ---TTGCTATA ---TTGCTATG
# --TTGCTATAA --TTGCTATGA
# -TTGCTATAAA -TTGCTATGAA
# TTGCTATAAAA TTGCTATGAAA
# TGCTATAAAAT TGCTATGAAAT
# GCTATAAAATA GCTATGAAATA
# CTATAAAATAA CTATGAAATAA
# TATAAAATAAA TATGAAATAAA
# ATAAAATAAAA ATGAAATAAAA
# TAAAATAAAAA TGAAATAAAAA
# AAAATAAAAAG GAAATAAAAAG
# AAATAAAAAGA AAATAAAAAGA
# True
# AATAAAAAGAT AATAAAAAGAA
# ATAAAAAGATA ATAAAAAGAAA
# TAAAAAGATAC TAAAAAGAAAC
# AAAAAGATACT AAAAAGAAACT
# AAAAGATACTG AAAAGAAACTG
# AAAGATACTGG AAAGAAACTGG
# AAGATACTGGA AAGAAACTGGA
# AGATACTGGAA AGAAACTGGAA
# GATACTGGAAA GAAACTGGAAA
# ATACTGGAAAT AAACTGGAAAT
# TACTGGAAATA AACTGGAAATA
# ACTGGAAATAG ACTGGAAATAG
# True
# CTGGAAATAGA CTGGAAATAGA
# True
# TGGAAATAGAA TGGAAATAGAA
# True
# GGAAATAGAAG GGAAATAGAAG
# True
# GAAATAGAAGC GAAATAGAAGC
# True
# AAATAGAAGCA AAATAGAAGCA
# True
# AATAGAAGCAT AATAGAAGCAA
# ATAGAAGCATC ATAGAAGCAAC
# TAGAAGCATCT TAGAAGCAACC
# AGAAGCATCTG AGAAGCAACCA
# GAAGCATCTGG GAAGCAACCAG
# AAGCATCTGGG AAGCAACCAGG
# AGCATCTGGGC AGCAACCAGGC
# GCATCTGGGCC GCAACCAGGCC
# CATCTGGGCCA CAACCAGGCCA
# ATCTGGGCCAT AACCAGGCCAT
# TCTGGGCCATA ACCAGGCCATA
# CTGGGCCATAG CCAGGCCATAG
# TGGGCCATAGC CAGGCCATAGC
# GGGCCATAGCT AGGCCATAGCT
# GGCCATAGCTG GGCCATAGCTG
# True
# GCCATAGCTGT GCCATAGCTGT
# True
# CCATAGCTGTA CCATAGCTGTG
# CATAGCTGTAT CATAGCTGTGT
# ATAGCTGTATT ATAGCTGTGTT
# TAGCTGTATTG TAGCTGTGTTG
# AGCTGTATTGG AGCTGTGTTGG
# GCTGTATTGGA GCTGTGTTGGA
# CTGTATTGGAA CTGTGTTGGAA
# TGTATTGGAAA TGTGTTGGAAA
# GTATTGGAAAT GTGTTGGAAAT
# TATTGGAAAT- TGTTGGAAAT-
# ATTGGAAAT-A GTTGGAAAT-A
# TTGGAAAT-AT TTGGAAAT-AT
# True
# TGGAAAT-ATG TGGAAAT-ATG
# True
# GGAAAT-ATGT GGAAAT-ATGT
# True
# GAAAT-ATGTT GAAAT-ATGTT
# True
# AAAT-ATGTTT AAAT-ATGTTT
# True
# AAT-ATGTTTG AAT-ATGTTTG
# True
# AT-ATGTTTGC AT-ATGTTTGC
# True
# T-ATGTTTGCT T-ATGTTTGCT
# True
# -ATGTTTGCTC -ATGTTTGCT-
# ATGTTTGCTC- ATGTTTGCT--
# TGTTTGCTC-- TGTTTGCT---
# GTTTGCTC--- GTTTGCT----
# TTTGCTC---C TTTGCT----C
# TTGCTC---CA TTGCT----CA
# TGCTC---CAT TGCT----CAC
# GCTC---CATC GCT----CACG
# CTC---CATC- CT----CACG-
# TC---CATC-T T----CACG-T
# C---CATC-T- ----CACG-TG
# ---CATC-T-- ---CACG-TGT
# --CATC-T--C --CACG-TGTC
# -CATC-T--CA -CACG-TGTCA
# CATC-T--CAC CACG-TGTCAC
# ATC-T--CACT ACG-TGTCACT
# TC-T--CACTG CG-TGTCACTG
# C-T--CACTGA G-TGTCACTGA
# -T--CACTGA- -TGTCACTGA-
# T--CACTGA-- TGTCACTGA--
# --CACTGA--G GTCACTGA--G
# -CACTGA--GA TCACTGA--GA
# CACTGA--GA- CACTGA--GA-
# True
# ACTGA--GA-- ACTGA--GA--
# True
# CTGA--GA--T CTGA--GA--T
# True
# TGA--GA--TT TGA--GA--TT
# True
# GA--GA--TTA GA--GA--TTA
# True
# A--GA--TTAA A--GA--TTAA
# True
# --GA--TTAAA --GA--TTAAA
# True
# -GA--TTAAAA -GA--TTAAAA
# True
# GA--TTAAAAC GA--TTAAAAC
# True
# A--TTAAAACA A--TTAAAACA
# True
# --TTAAAACAG --TTAAAACAG
# True
# -TTAAAACAGG -TTAAAACAGG
# True
# TTAAAACAGGA TTAAAACAGGA
# True
# TAAAACAGGAA TAAAACAGGAA
# True
# AAAACAGGAAA AAAACAGGAAA
# True
# AAACAGGAAA- AAACAGGAAA-
# True
# AACAGGAAA-C AACAGGAAA-C
# True
# ACAGGAAA-CC ACAGGAAA-CC
# True
# CAGGAAA-CCA CAGGAAA-CCA
# True
# AGGAAA-CCAC AGGAAA-CCAC
# True
# GGAAA-CCACC GGAAA-CCACC
# True
# GAAA-CCACCA GAAA-CCACCA
# True
# AAA-CCACCAA AAA-CCACCAG
# AA-CCACCAAT AA-CCACCAGT
# A-CCACCAAT- A-CCACCAGT-
# -CCACCAAT-A -CCACCAGT-A
# CCACCAAT-AA CCACCAGT-AC
# CACCAAT-AAA CACCAGT-ACA
# ACCAAT-AAAA ACCAGT-ACAA
# CCAAT-AAAAG CCAGT-ACAAG
# CAAT-AAAAGG CAGT-ACAAGG
# AAT-AAAAGGC AGT-ACAAGGC
# AT-AAAAGGCA GT-ACAAGGCC
# T-AAAAGGCAC T-ACAAGGCCC
# -AAAAGGCAC- -ACAAGGCCC-
# AAAAGGCAC-- ACAAGGCCC--
# AAAGGCAC--- CAAGGCCC---
# AAGGCAC---- AAGGCCC----
# AGGCAC----A AGGCCC----A
# GGCAC----AT GGCCC----AT
# GCAC----ATT GCCC----ATT
# CAC----ATTT CCC----ATTT
# AC----ATTTC CC----ATTTC
# C----ATTTCA C----ATTTCA
# True
# ----ATTTCAT ----ATTTCAT
# True
# ---ATTTCATC ---ATTTCATC
# True
# --ATTTCATCA --ATTTCATC-
# -ATTTCATCAG -ATTTCATC-G
# ATTTCATCAGT ATTTCATC-GT
# TTTCATCAGTG TTTCATC-GTG
# TTCATCAGTGA TTCATC-GTGA
# TCATCAGTGAC TCATC-GTGAC
# CATCAGTGACT CATC-GTGACT
# ATCAGTGACTT ATC-GTGACTT
# TCAGTGACTTC TC-GTGACTTC
# CAGTGACTTCC C-GTGACTTCC
# AGTGACTTCCA -GTGACTTCCA
# GTGACTTCCAC GTGACTTCCAC
# True
# TGACTTCCACA TGACTTCCACG
# GACTTCCACAG GACTTCCACGG
# ACTTCCACAGG ACTTCCACGGA
# CTTCCACAGGA CTTCCACGGAA
# TTCCACAGGAA TTCCACGGAAA
# TCCACAGGAAT TCCACGGAAAT
# CCACAGGAATG CCACGGAAATG
# CACAGGAATGC CACGGAAATGC
# ACAGGAATGCT ACGGAAATGCT
# CAGGAATGCTC CGGAAATGCTC
# AGGAATGCTCG GGAAATGCTCA
# GGAATGCTCGT GAAATGCTCAT
# GAATGCTCGTC AAATGCTCATC
# AATGCTCGTCC AATGCTCATCC
# ATGCTCGTCCT ATGCTCATCCT
# TGCTCGTCCTC TGCTCATCCTT
# GCTCGTCCTC- GCTCATCCTT-
# CTCGTCCTC-- CTCATCCTT--
# TCGTCCTC--A TCATCCTT--G
# CGTCCTC--AC CATCCTT--GC
# GTCCTC--ACG ATCCTT--GCC
# TCCTC--ACGA TCCTT--GCCT
# CCTC--ACGA- CCTT--GCCT-
# CTC--ACGA-- CTT--GCCT--
# TC--ACGA--- TT--GCCT---
# C--ACGA---- T--GCCT----
# --ACGA----- --GCCT-----
# -ACGA------ -GCCT------
# ACGA------- GCCT-------
# CGA-------- CCT--------
# GA--------- CT---------
# A---------- T----------
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------- -----------
# True
# ----------G ----------G
# True
# ---------GC ---------GC
# True
# --------GCA --------GCA
# True
# -------GCAT -------GCAT
# True
# ------GCATA ------GCATA
# True
# -----GCATA- -----GCATA-
# True
# ----GCATA-T ----GCATA-C
# ---GCATA-TA ---GCATA-CA
# --GCATA-TAG --GCATA-CAG
# -GCATA-TAGA -GCATA-CAGA
# GCATA-TAGAC GCATA-CAGAC
# CATA-TAGACA CATA-CAGACA
# ATA-TAGACAC ATA-CAGACAC
# TA-TAGACACT TA-CAGACACG
# A-TAGACACTG A-CAGACACGG
# -TAGACACTGA -CAGACACGGA
# TAGACACTGAG CAGACACGGAG
# AGACACTGAGG AGACACGGAGG
# GACACTGAGGC GACACGGAGGC
# ACACTGAGGCC ACACGGAGGCC
# CACTGAGGCCA CACGGAGGCCA
# ACTGAGGCCAT ACGGAGGCCAT
# CTGAGGCCATC CGGAGGCCATC
# TGAGGCCATCC GGAGGCCATCC
# GAGGCCATCCT GAGGCCATCCT
# True
# AGGCCATCCTT AGGCCATCCTT
# True
# GGCCATCCTTC GGCCATCCTTC
# True
# GCCATCCTTCG GCCATCCTTCG
# True
# CCATCCTTCGA CCATCCTTCGA
# True
# CATCCTTCGAA CATCCTTCGAA
# True
# ATCCTTCGAAG ATCCTTCGAAG
# True
# TCCTTCGAAGA TCCTTCGAAGA
# True

# %%
label_encoder = LabelEncoder()
label_encoder.fit(np.array(['a','c','g','t','0', 'z']))
encoder = OneHotEncoder(sparse=False, dtype=int, categories=[range(6)])
def one_hot_encoder(my_array, encoder):
    integer_encoded = label_encoder.transform(my_array)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_encoded = encoder.fit_transform(integer_encoded)
    #onehot_encoded = np.delete(onehot_encoded, -1, 1)
    return onehot_encoded, encoder

def alignBoth(alignList):
    zeros = '00000'
    h, w = len(alignList), 2;
    Matrix = [[0 for x in range(w)] for y in range(h)]
    for i in range(len(alignList)):
        for j in range(len(alignList[i])):
            Matrix[i][j] = one_hot_encoder(string_to_array(str(alignList[i][j].seq).upper()), encoder)
    return Matrix

# [Index of alignment][1 for Ancester, 0 for Descendant][Always 0]
one_hot_aligned = alignBoth(alignList)
#one_hot_aligned = one_hot_aligned[:][:][0]
one_hot_aligned = np.array(one_hot_aligned)
#print(one_hot_aligned.shape)
#ignorethis, encoder = one_hot_encoder(string_to_array(str(alignList[1][1].seq)),encoder)


print(type(one_hot_aligned))
print(len(one_hot_aligned[126][1]))
print(one_hot_aligned[126][1][0])
#print(encoder.inverse_transform(one_hot_aligned[126][1]))
print(type(one_hot_aligned[126][1]))
# A = [1 0 0 0], C = [0 1 0 0], G = [0 0 1 0], T = [0 0 0 1]
def decoder(array):
    result = ""
    size = len(array)
    for i in range(size):
        if array[i].tolist() == [1, 0, 0, 0, 0, 0]:
            result=result+"0" 
        elif array[i].tolist() == [0, 1, 0, 0, 0, 0]:
            result=result+"A"
        elif array[i].tolist() == [0, 0, 1, 0, 0, 0]:
            result=result+"C"
        elif array[i].tolist() == [0, 0, 0, 1, 0, 0]:
            result=result+"G"
        elif array[i].tolist() == [0, 0, 0, 0, 1, 0]:
            result=result+"T"
        elif array[i].tolist() == [0, 0, 0, 0, 0, 1]:
            result=result+"-"
    return result

def decoderY(array):
    result = ""    
    if array.tolist() == [1, 0, 0, 0, 0, 0]:
        result=result+"0" 
    elif array.tolist() == [0, 1, 0, 0, 0, 0]:
        result=result+"A"
    elif array.tolist() == [0, 0, 1, 0, 0, 0]:
        result=result+"C"
    elif array.tolist() == [0, 0, 0, 1, 0, 0]:
        result=result+"G"
    elif array.tolist() == [0, 0, 0, 0, 1, 0]:
        result=result+"T"
    elif array.tolist() == [0, 0, 0, 0, 0, 1]:
        result=result+"-"
    return result
    
print(decoder(one_hot_aligned[126][1][0]))
print(len(one_hot_aligned))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a874356283e6> in <module>
#      19
#      20 # [Index of alignment][1 for Ancester, 0 for Descendant][Always 0]
# ---> 21 one_hot_aligned = alignBoth(alignList)
#      22 #one_hot_aligned = one_hot_aligned[:][:][0]
#      23 one_hot_aligned = np.array(one_hot_aligned)
#
# NameError: name 'alignList' is not defined

# %%
def vectorize(char_setx, char_sety, sequence_length):
    dataX = []
    dataY = []
    dataX1 = []
    dataY1 = []
    result=[]
    char_setx, char_sety = mutation_with_gap(char_setx, char_sety)
    #print(type(char_sety[0]))
    for i in range(len(char_setx) - sequence_length):
        
        '''for i in char_sety[i: i + sequence_length-1]:
            y1.append(i)'''
        #x1 = char_setx1[i: i + sequence_length]
        x = char_setx[i:i + sequence_length]
        y = char_sety[i: i + sequence_length]
        y1 = [[1, 0, 0, 0, 0, 0]]
        temp = y[:-1]
        #temp = temp.tolist()
        for i in temp:
            y1.append(i)
        y1=np.array(y1)
        dataX.append(x)
        dataY.append(y)
        dataY1.append(y1)

    return dataX, dataY, dataY1

def tokenize(one_hot_aligned, sequence_length):
    X = []
    Y = []
    X1 = []
    Y1 = []
    for i in range(len(one_hot_aligned)):
        dataX, dataY, dataY1 = vectorize(one_hot_aligned[i][1][0], one_hot_aligned[i][0][0],  sequence_length)
        X.extend(dataX)
        Y.extend(dataY)
        #X1.extend(dataX1)
        Y1.extend(dataY1)
    return X, Y, Y1

def truncate(one_hot_aligned):
    X = []
    Y = []
    for i in range(len(one_hot_aligned)):
        X.append(one_hot_aligned[i][1][0])
        Y.append(one_hot_aligned[i][0][0])
    X = sequence.pad_sequences(X,
                                 maxlen=30,
                                 truncating='post',
                                 padding='post',
                                 value=0)
    Y = sequence.pad_sequences(Y,
                                 maxlen=30,
                                 truncating='post',
                                 padding='post',
                                 value=0)
    return X,Y

# function for checking if there are at least one mutation and there are no gaps.
def mutation_with_nogap(a, b):
    a = a.tolist()
    b = b.tolist()
    if a.count([0,0,0,0,0,1])>0 or b.count([0,0,0,0,0,1])>0:
        return False
    else:
        return True
    
def mutation_with_gap(a, b):
    a = a.tolist()
    b = b.tolist()
    a_new = []
    b_new = []
    for i, j in zip(a,b):
        if i == [0,0,0,0,0,1] and j == [0,0,0,0,0,1]:
            continue
        else:
            a_new.append(i)
            b_new.append(j)
    return a_new, b_new
        


def diffList(a, b):
    count = 0
    length = len(a)
    for i in range(length):
        if a[i] != b[i]:
            count = count+1
    return count

def deleteGap(one_hot_aligned):
    result = one_hot_aligned
    for i in range(len(one_hot_aligned)):
        if one_hot_aligned[i][1][0] == '-' and one_hot_aligned[i][0][0] == '-':
            result.pop(i)
    return result

# Used for non 0 padding
#one_hot_aligned = deleteGap(one_hot_aligned)
X, Y, Y1=tokenize(one_hot_aligned, seq_length)

# Used for 0 padding
#X, Y = truncate(one_hot_aligned)
X = np.array(X)
Y = np.array(Y)
#X1 = np.array(X1)
Y1 = np.array(Y1)

print(Y.shape)
print(len(X))
pt1 = 9600000
pt2 = 9650000
pt3 = 9700000
X_train = X[:pt1]
X_val = X[pt1:pt2]
X_test = X[pt2:pt3]
y_train = Y[:pt1]
y_val =  Y[pt1:pt2]
y_test = Y[pt2:pt3]
# X_train1 = X1[:pt1]
# X_val1 = X1[pt1:pt2]
# X_test1 = X1[pt2:pt3]
y_train1 = Y1[:pt1]
y_val1 =  Y1[pt1:pt2]
y_test1 = Y1[pt2:pt3]

# X_train = X[:20000]
# X_val = X[20000:23000]
# X_test = X[23000:26000]
# y_train = Y[:20000]
# y_val =  Y[20000:23000]
# y_test = Y[23000:26000]

np.save('prepData/X_train_camFam3_v3_chr2_size11', X_train)
np.save('prepData/X_val_camFam3_v3_chr2_size11', X_val)
np.save('prepData/X_test_camFam3_v3_chr2_size11', X_test)
np.save('prepData/y_train_camFam3_v3_chr2_size11', y_train)
np.save('prepData/y_val_camFam3_v3_chr2_size11', y_val)
np.save('prepData/y_test_camFam3_v3_chr2_size11', y_test)

np.save('prepData/y_train1_camFam3_v3_chr2_size11', y_train1)
np.save('prepData/y_val1_camFam3_v3_chr2_size11', y_val1)
np.save('prepData/y_test1_camFam3_v3_chr2_size11', y_test1)

# np.save('prepData/X_train1_camFam3_1mutOnly_v2', X_train1)
# np.save('prepData/X_val1_camFam3_1mutOnly_v2', X_val1)
# np.save('prepData/X_test1_camFam3_1mutOnly_v2', X_test1)


# np.save('prepData20/X_train_camFam3_1mutOnly', X_train)
# np.save('prepData20/X_val_camFam3_1mutOnly', X_val)
# np.save('prepData20/X_test_camFam3_1mutOnly', X_test)
# np.save('prepData20/y_train_camFam3_1mutOnly', y_train)
# np.save('prepData20/y_val_camFam3_1mutOnly', y_val)
# np.save('prepData20/y_test_camFam3_1mutOnly', y_test)

print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(X_train[0])
print(y_train[0])
print(y_train1[0])

# %%
# import difflib
# sm=difflib.SequenceMatcher(None,X_test,X_train)
# sm2=difflib.SequenceMatcher(None,y_test,y_train)
for i in range(100):
    print(i, decoder(X[i]))

# %%
for i in range(100):
    print(i, decoder(Y[i]))

# %%
for i in range(100):
    print(i, decoder(Y1[i]))
